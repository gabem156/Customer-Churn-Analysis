# %% [markdown]
#  # Customer Churn Analysis
#
# ## Project Goal
# This project analyzes customer churn behavior to identify the factors contributing to customer loss and provide actionable business insights for improving customer retention.
#
# ## Objectives
# - Clean and prepare customer data
# - Explore churn trends
# - Identify churn drivers
# - Visualize customer behavior
# - Generate business recommendations
#
# ## Tools Used
# - Python
# - Pandas
# - Matplotlib
# - Seaborn
# - Tableau (optional)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/blastchar/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv

# %%
df = pd.read_csv('/kaggle/input/datasets/blastchar/telco-customer-churn/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# ## Data Exploration

# %%
# Checking for missing values to identify potential data quality issues
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# Check duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Statistical summary
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
#The overall churn rate
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# The visualization below provides a clear overview of customer churn behavior within the dataset.
sns.countplot(x='Churn', data=df)
plt.title('Customer Churn Distribution')
plt.show()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Data Cleaning
# - Converted TotalCharges to numeric format
# - Removed missing values
# - Verified data quality before analysis

# %%
#Clean the data
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
#Fix TotalCharges
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
df['TotalCharges'].isnull().sum()
# Out:
# np.int64(11)

# %%
#Remove missing rows
df.dropna(inplace=True)

# %%
#Verify
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Analyze churn by demographics

# %%
#Gender vs churn
sns.countplot(x='gender', hue='Churn', data=df)
plt.title('Churn by Gender')
plt.show()

# %%
#Senior citizens vs churn
sns.countplot(x='SeniorCitizen', hue='Churn', data=df)
plt.title('Churn by Senior Citizen Status')
plt.show()

# %%
#Contract type vs churn
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title('Churn by Contract Type')
plt.xticks(rotation=15)
plt.show()

# %% [markdown]
# # Monthly charges analysis

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title('Monthly Charges by Churn')
plt.show()

# %% [markdown]
# # Internet service analysis

# %%
sns.countplot(x='InternetService', hue='Churn', data=df)
plt.title('Churn by Internet Service')
plt.show()

# %% [markdown]
# # Tenure analysis

# %%
sns.histplot(data=df, x='tenure', hue='Churn', multiple='stack')
plt.title('Customer Tenure Distribution')
plt.show()

# %% [markdown]
# # Correlation heatmap

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# %%
plt.figure(figsize=(10,6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Key Insights
#
# - Customers on month-to-month contracts showed the highest churn rates
# - Customers with higher monthly charges were more likely to churn
# - Short-tenure customers had significantly higher churn behavior
# - Fiber optic internet users showed elevated churn levels
# - Long-term contract customers demonstrated stronger retention

# %%
## Business Recommendations

- Encourage customers to transition to long-term contracts
- Improve onboarding for new customers to reduce early churn
- Investigate pricing concerns among high monthly charge customers
- Develop retention campaigns targeting high-risk customer groups
# Out:
#   File "/tmp/ipykernel_16/2286465108.py", line 3
#     - Encourage customers to transition to long-term contracts
#                 ^
# SyntaxError: invalid syntax

# %%
df.to_csv('telco_customer_churn_cleaned.csv', index=False)

# %%
import os
os.listdir()
